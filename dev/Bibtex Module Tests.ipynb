# %%
import sys
sys.path.append('..')
import bibtex.bibtex as bb
cits = bb.Bibtex()
cits.process_citations('../data/bibtex/train', 'txt')

# %%
cits.predict_citation_label(pattern="original")
# Out:
# NB: the same doc format is assumed from the training data: txt
#   number abstract                                              title  \
# 0      1        Y                                Accepting Evolution
# 1      6        Y                            Museums Teach Evolution
# 2      1        Y  How can we detect introduced mammalian predato...
# 3      6        Y  Toward an Anthropology of Computer-Mediated, A...
# 4      4        Y               Functions and Dimensions of Religion
# 5      2        Y  Toward an Integrative Theory for\nUnderstandin...
#
#                                            publisher      pages volume  \
# 0        [Society for the Study of Evolution, Wiley]    248-254     62
# 1        [Society for the Study of Evolution, Wiley]  1500-1506     61
# 2                     New Zealand Ecological Society     86-102     38
# 3  [The University of Chicago Press, Wenner-Gren ...    716-739     54
# 4  [Oxford University Press, Association for the ...    263-272     35
# 5                       University of Illinois Press      44-56     40
#
#                  ISSN                                             author  \
# 0  00143820, 15585646                  Anusuya Chinsamy and Éva Plagányi
# 1  00143820, 15585646                 Judy Diamond and E. Margaret Evans
# 2  01106465, 11777788  Georgina A. Pickerell and Colin F. J. O'Donnel...
# 3  00113204, 15375382                                         Eitan Wilf
# 4            00380210                                       L. D. Nelson
# 5  07360770, 21518009                          Ephrat Huss and Haim Maor
#
#    year                                                URL  \
# 0  2008                http://www.jstor.org/stable/4627133
# 1  2007                http://www.jstor.org/stable/4621393
# 2  2014               http://www.jstor.org/stable/24060826
# 3  2013         http://www.jstor.org/stable/10.1086/673321
# 4  1974                http://www.jstor.org/stable/3710610
# 5  2014  http://www.jstor.org/stable/10.5406/visuartsre...
#
#                           journal                      prediction
# 0                       Evolution                       Evolution
# 1                       Evolution                       Evolution
# 2  New Zealand Journal of Ecology  New Zealand Journal of Ecology
# 3            Current Anthropology            Current Anthropology
# 4           Sociological Analysis            Current Anthropology
# 5            Visual Arts Research                       Evolution
