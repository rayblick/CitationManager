# %%
import sys
sys.path.append('..')
import bibtex.bibtex as bb
cits = bb.Bibtex()
cits.process_citations('../data/bibtex/train', 'txt')

# %%
cits.predict_citation_label(pattern="original")
# Out:
# NB: the same doc format is assumed from the training data: txt
#                                                title                ISSN  \
# 0                            Museums Teach Evolution  00143820, 15585646
# 1               Functions and Dimensions of Religion            00380210
# 2  Toward an Integrative Theory for\nUnderstandin...  07360770, 21518009
# 3  Toward an Anthropology of Computer-Mediated, A...  00113204, 15375382
# 4  How can we detect introduced mammalian predato...  01106465, 11777788
# 5                                Accepting Evolution  00143820, 15585646
#
#                                               author  \
# 0                 Judy Diamond and E. Margaret Evans
# 1                                       L. D. Nelson
# 2                          Ephrat Huss and Haim Maor
# 3                                         Eitan Wilf
# 4  Georgina A. Pickerell and Colin F. J. O'Donnel...
# 5                  Anusuya Chinsamy and Éva Plagányi
#
#                           journal volume abstract  \
# 0                       Evolution     61        Y
# 1           Sociological Analysis     35        Y
# 2            Visual Arts Research     40        Y
# 3            Current Anthropology     54        Y
# 4  New Zealand Journal of Ecology     38        Y
# 5                       Evolution     62        Y
#
#                                                  URL  \
# 0                http://www.jstor.org/stable/4621393
# 1                http://www.jstor.org/stable/3710610
# 2  http://www.jstor.org/stable/10.5406/visuartsre...
# 3         http://www.jstor.org/stable/10.1086/673321
# 4               http://www.jstor.org/stable/24060826
# 5                http://www.jstor.org/stable/4627133
#
#                                            publisher number  year      pages  \
# 0        [Society for the Study of Evolution, Wiley]      6  2007  1500-1506
# 1  [Oxford University Press, Association for the ...      4  1974    263-272
# 2                       University of Illinois Press      2  2014      44-56
# 3  [The University of Chicago Press, Wenner-Gren ...      6  2013    716-739
# 4                     New Zealand Ecological Society      1  2014     86-102
# 5        [Society for the Study of Evolution, Wiley]      1  2008    248-254
#
#                        prediction
# 0                       Evolution
# 1            Current Anthropology
# 2                       Evolution
# 3            Current Anthropology
# 4  New Zealand Journal of Ecology
# 5                       Evolution
